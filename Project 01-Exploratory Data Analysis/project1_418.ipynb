# %%
# Hamza Shahid
# Netid: Hshahi2
# Joshua Herman
# Netid: jherma20
# Muhammad Abdullah Umar
# Netid: mumar4
# Project 1

# %%
# load libraries 
import pandas as pd
pd.set_option('display.max_columns',100)
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
# load the dataset using pandas.read_csv
DEMOGRAPHICS_DATA = pd.read_csv('demographics_train.csv')
ELECTIONS_DATA = pd.read_csv('election_train.csv')

# %%
# TASK 1 - delete the word " County" and " Parish" from the county column
DEMOGRAPHICS_DATA['County'] = DEMOGRAPHICS_DATA['County'].str.replace(' County','')
DEMOGRAPHICS_DATA['County'] = DEMOGRAPHICS_DATA['County'].str.replace(' Parish','')
DEMOGRAPHICS_DATA.head()
# Out:
#     County State  2014 Population  2010 Population  Population Percent Change  \
# 0  Clinton    IN            32776            33224                       -1.3
# 1    Trego    KS             2902             3001                       -3.3
# 2     Cass    NE            25524            25241                        1.1
# 3   Walton    GA            87615            83768                        4.6
# 4  Norfolk    MA           692254           670850                        3.2
#
#    Percent Under 5 Years  Percent Under 18 Years  Percent 65 and Older  \
# 0                    6.9                    26.3                  15.8
# 1                    4.4                    18.0                  24.2
# 2                    6.0                    24.6                  16.1
# 3                    6.2                    25.9                  14.2
# 4                    5.4                    21.6                  15.7
#
# ...

# %%
# TASK 1 CONTINUED - change state names to abbreviated names  
abbreviated = {'Alabama':'AL','Alaska':'AK','Arizona':'AZ','Arkansas':'AR','California':'CA','Colorado':'CO',
               'Connecticut': 'CT','Delaware': 'DE','Florida': 'FL','Georgia':'GA','Hawaii':'HI','Idaho':'ID',
               'Illinois':'IL','Indiana':'IN','Iowa':'IA','Kansas':'KS','Kentucky':'KY','Louisiana':'LA',
               'Maine':'ME','Maryland':'MD','Massachusetts':'MA','Michigan':'MI','Minnesota':'MN','Mississippi':'MS',
               'Missouri':'MO','Montana':'MT','Nebraska':'NE','Nevada':'NV','New Hampshire':'NH','New Jersey': 'NJ',
               'New Mexico':'NM','New York':'NY','North Carolina':'NC','North Dakota':'ND','Ohio':'OH','Oklahoma':'OK',
               'Oregon': 'OR','Pennsylvania':'PA','Rhode Island': 'RI','South Carolina':'SC','South Dakota': 'SD',
               'Tennessee':'TN','Texas':'TX','Utah':'UT','Vermont':'VT','Virginia':'VA','Washington':'WA',
               'West Virginia':'WV','Wisconsin':'WI','Wyoming':'WY'}

ELECTIONS_DATA['State'] = ELECTIONS_DATA['State'].map(abbreviated)

# %%
# TASK 1 CONTINUED - delete the word " Plt." from the county column
ELECTIONS_DATA['County'] = ELECTIONS_DATA['County'].str.replace(' Plt.','')
ELECTIONS_DATA.head()
# Out:
#     County State  Ben Carson.Number of Votes Ben Carson.Party  \
# 0  Clinton    IN                           0       Republican
# 1     Cass    NE                           0       Republican
# 2   Walton    GA                        1046       Republican
# 3  Norfolk    MA                          38       Republican
# 4   Beaver    PA                           0       Republican
#
#    Ben Carson.Percent of Votes  Bernie Sanders.Number of Votes  \
# 0                          0.0                            1046
# 1                          0.0                             151
# 2                          5.5                             969
# 3                          2.2                             956
# 4                          0.0                            9563
#
#   Bernie Sanders.Party  Bernie Sanders.Percent of Votes  \
# 0             Democrat                             59.1
# 1             Democrat                             53.4
# ...

# %%
## TASK 1 CONTINUED - merge the two datasets using inner join on the county and state and display the merged dataset
MERGED_DATA=pd.merge(ELECTIONS_DATA,DEMOGRAPHICS_DATA,how='inner',on=['County','State'])
MERGED_DATA
# Out:
#               County State  Ben Carson.Number of Votes Ben Carson.Party  \
# 0            Clinton    IN                           0       Republican
# 1               Cass    NE                           0       Republican
# 2             Walton    GA                        1046       Republican
# 3            Norfolk    MA                          38       Republican
# 4             Beaver    PA                           0       Republican
# 5           Sedgwick    CO                           0       Republican
# 6            Clatsop    OR                           0       Republican
# 7             Forest    PA                           0       Republican
# 8             Barton    MO                           0       Republican
# 9          McCurtain    OK                         124       Republican
# 10           Screven    GA                         144       Republican
# 11         Humphreys    MS                           0       Republican
# ...

# %%
# TASK 2 - explore the merged dataset and display the number of variables in the dataset
# (num1- rows, num2- variables/columns)
MERGED_DATA.shape
# Out:
# (2115, 89)

# %%
# TASK 2 CONTINUED - dropping missing columns
MERGED_DATA.drop(['No Preference.Party','Uncommitted.Party'],axis=1, inplace=True)
MERGED_DATA.head()
# Out:
#     County State  Ben Carson.Number of Votes Ben Carson.Party  \
# 0  Clinton    IN                           0       Republican
# 1     Cass    NE                           0       Republican
# 2   Walton    GA                        1046       Republican
# 3  Norfolk    MA                          38       Republican
# 4   Beaver    PA                           0       Republican
#
#    Ben Carson.Percent of Votes  Bernie Sanders.Number of Votes  \
# 0                          0.0                            1046
# 1                          0.0                             151
# 2                          5.5                             969
# 3                          2.2                             956
# 4                          0.0                            9563
#
#   Bernie Sanders.Party  Bernie Sanders.Percent of Votes  \
# 0             Democrat                             59.1
# 1             Democrat                             53.4
# ...

# %%
# TASK 2 CONTINUED - type of variables in the dataset
MERGED_DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2115 entries, 0 to 2114
# Data columns (total 87 columns):
# County                                                2115 non-null object
# State                                                 2115 non-null object
# Ben Carson.Number of Votes                            2115 non-null int64
# Ben Carson.Party                                      2115 non-null object
# Ben Carson.Percent of Votes                           2115 non-null float64
# Bernie Sanders.Number of Votes                        2115 non-null int64
# Bernie Sanders.Party                                  2115 non-null object
# Bernie Sanders.Percent of Votes                       2115 non-null float64
# Carly Fiorina.Number of Votes                         2115 non-null int64
# Carly Fiorina.Party                                   2115 non-null object
# Carly Fiorina.Percent of Votes                        2115 non-null float64
# ...

# %%
# TASK 3 - create a new variable named “Democratic” that contains the number of votes cast for candidates from 
# the Democratic party in each county
MERGED_DATA['Democratic'] = MERGED_DATA['Bernie Sanders.Number of Votes']+MERGED_DATA['Hillary Clinton.Number of Votes']+MERGED_DATA['Martin O\'Malley.Number of Votes'] 
MERGED_DATA.head()
# Out:
#     County State  Ben Carson.Number of Votes Ben Carson.Party  \
# 0  Clinton    IN                           0       Republican
# 1     Cass    NE                           0       Republican
# 2   Walton    GA                        1046       Republican
# 3  Norfolk    MA                          38       Republican
# 4   Beaver    PA                           0       Republican
#
#    Ben Carson.Percent of Votes  Bernie Sanders.Number of Votes  \
# 0                          0.0                            1046
# 1                          0.0                             151
# 2                          5.5                             969
# 3                          2.2                             956
# 4                          0.0                            9563
#
#   Bernie Sanders.Party  Bernie Sanders.Percent of Votes  \
# 0             Democrat                             59.1
# 1             Democrat                             53.4
# ...

# %%
# TASK 4 - create a new variable named “Republican” that contains the number of votes cast for candidates 
# from the Republican party in each county
MERGED_DATA['Republican'] = MERGED_DATA['Ben Carson.Number of Votes']+MERGED_DATA['Carly Fiorina.Number of Votes']+MERGED_DATA['Chris Christie.Number of Votes'] +MERGED_DATA['Donald Trump.Number of Votes'] +MERGED_DATA['Jeb Bush.Number of Votes'] +MERGED_DATA['John Kasich.Number of Votes'] +MERGED_DATA['Marco Rubio.Number of Votes'] +MERGED_DATA['Mike Huckabee.Number of Votes'] +MERGED_DATA['Rand Paul.Number of Votes'] +MERGED_DATA['Rick Santorum.Number of Votes']+MERGED_DATA['Ted Cruz.Number of Votes']
MERGED_DATA.head()
# Out:
#     County State  Ben Carson.Number of Votes Ben Carson.Party  \
# 0  Clinton    IN                           0       Republican
# 1     Cass    NE                           0       Republican
# 2   Walton    GA                        1046       Republican
# 3  Norfolk    MA                          38       Republican
# 4   Beaver    PA                           0       Republican
#
#    Ben Carson.Percent of Votes  Bernie Sanders.Number of Votes  \
# 0                          0.0                            1046
# 1                          0.0                             151
# 2                          5.5                             969
# 3                          2.2                             956
# 4                          0.0                            9563
#
#   Bernie Sanders.Party  Bernie Sanders.Percent of Votes  \
# 0             Democrat                             59.1
# 1             Democrat                             53.4
# ...

# %%
# TASK 5 - create a new variable named “Party” that labels each county as Democratic or Republican. This new variable 
# should be equal to 1 if there were more votes cast for candidates from the Democratic party than the Republican
# party in that county and it should be equal to 0 otherwise
MERGED_DATA['Party'] = (MERGED_DATA['Democratic'] > MERGED_DATA['Republican']).astype(int)
MERGED_DATA
# Out:
#               County State  Ben Carson.Number of Votes Ben Carson.Party  \
# 0            Clinton    IN                           0       Republican
# 1               Cass    NE                           0       Republican
# 2             Walton    GA                        1046       Republican
# 3            Norfolk    MA                          38       Republican
# 4             Beaver    PA                           0       Republican
# 5           Sedgwick    CO                           0       Republican
# 6            Clatsop    OR                           0       Republican
# 7             Forest    PA                           0       Republican
# 8             Barton    MO                           0       Republican
# 9          McCurtain    OK                         124       Republican
# 10           Screven    GA                         144       Republican
# 11         Humphreys    MS                           0       Republican
# ...

# %%
# TASK 6 - compute the mean population in 2014 for democratic counties
democraticPARTY = MERGED_DATA['Party'] == 1
democraticMEAN = MERGED_DATA.loc[democraticPARTY, '2014 Population'].mean()
democraticMEAN
# Out:
# 185786.7245614035

# %%
# TASK 6 CONTINUED - compute the mean population in 2014 for democratic counties
republicanPARTY = MERGED_DATA['Party'] == 0
republicanMEAN = MERGED_DATA.loc[republicanPARTY, '2014 Population'].mean()
republicanMEAN
# Out:
# 77988.65372168284

# %%
STDEV = MERGED_DATA['2014 Population'].std()
STDEV
# Out:
# 350368.006574168

# %%
from scipy import stats
stats.ttest_ind(republicanPARTY,democraticPARTY)
# Out:
# Ttest_indResult(statistic=33.77850619607116, pvalue=1.206709306944802e-221)

# %%
#T-test and p-val for the population
rvs5 = stats.norm.rvs(loc=8, scale=20, size=100)
#stats.ttest_ind(MERGED_DATA.loc[democraticPARTY, '2014 Population'],MERGED_DATA.loc[republicanPARTY, '2014 Population'])
stats.ttest_ind(MERGED_DATA.loc[democraticPARTY, '2014 Population'],MERGED_DATA.loc[republicanPARTY, '2014 Population'], equal_var = False)
# Out:
# Ttest_indResult(statistic=4.544147193705178, pvalue=6.584164225051351e-06)

# %%
#Mean of Median Democratic Household Income
demHouseHoldMEAN= MERGED_DATA.loc[democraticPARTY, 'Median Household Income'].mean()
demHouseHoldMEAN
# Out:
# 45643.87192982456

# %%
#Mean of Median Republican Household Income
RepHouseHoldMEAN= MERGED_DATA.loc[republicanPARTY, 'Median Household Income'].mean()
RepHouseHoldMEAN
# Out:
# 45268.803236245956

# %%
#T-test and p-val for the Median Household
rvs5 = stats.norm.rvs(loc=8, scale=20, size=100)
#stats.ttest_ind(MERGED_DATA.loc[democraticPARTY, '2014 Population'],MERGED_DATA.loc[republicanPARTY, '2014 Population'])
stats.ttest_ind(MERGED_DATA.loc[democraticPARTY, '2014 Population'],MERGED_DATA.loc[republicanPARTY, 'Median Household Income'], equal_var = False)
# Out:
# Ttest_indResult(statistic=6.116308071019074, pvalue=1.7811433799586417e-09)

# %%
PercentUnder5yrsDem = MERGED_DATA.loc[democraticPARTY, 'Percent Under 5 Years']
PercentUnder5yrsDem.describe()
# Out:
# count    570.000000
# mean       5.982807
# std        1.281922
# min        2.100000
# 25%        5.200000
# 50%        5.900000
# 75%        6.600000
# max       13.300000
# Name: Percent Under 5 Years, dtype: float64

# %%
PercentUnder18yrsDem = MERGED_DATA.loc[democraticPARTY, 'Percent Under 18 Years']
PercentUnder18yrsDem.describe()
# Out:
# count    570.000000
# mean      22.198947
# std        3.505687
# min       10.600000
# 25%       20.100000
# 50%       22.150000
# 75%       24.100000
# max       40.500000
# Name: Percent Under 18 Years, dtype: float64

# %%
PercentUnder65yrsDem = MERGED_DATA.loc[democraticPARTY, 'Percent 65 and Older']
PercentUnder65yrsDem.describe()
# Out:
# count    570.000000
# mean      16.223509
# std        3.701419
# min        7.100000
# 25%       13.700000
# 50%       16.100000
# 75%       18.400000
# max       29.700000
# Name: Percent 65 and Older, dtype: float64

# %%
PercentUnder5yrsRep = MERGED_DATA.loc[republicanPARTY, 'Percent Under 5 Years']
PercentUnder5yrsRep.describe()
# Out:
# count    1545.000000
# mean        5.808350
# std         1.152105
# min         1.500000
# 25%         5.100000
# 50%         5.800000
# 75%         6.400000
# max        10.600000
# Name: Percent Under 5 Years, dtype: float64

# %%
PercentUnder18yrsRep = MERGED_DATA.loc[republicanPARTY, 'Percent Under 18 Years']
PercentUnder18yrsRep.describe()
# Out:
# count    1545.000000
# mean       22.569256
# std         3.329192
# min         7.400000
# 25%        20.600000
# 50%        22.500000
# 75%        24.300000
# max        35.600000
# Name: Percent Under 18 Years, dtype: float64

# %%
PercentUnder65yrsRep = MERGED_DATA.loc[republicanPARTY, 'Percent 65 and Older']
PercentUnder65yrsRep.describe()
# Out:
# count    1545.000000
# mean       18.011521
# std         4.433460
# min         7.200000
# 25%        15.100000
# 50%        17.600000
# 75%        20.200000
# max        52.900000
# Name: Percent 65 and Older, dtype: float64

# %%
df = pd.DataFrame({"date_x":[2015]*3,
                   "Occurance_x":[5.982807, 22.198947, 16.223509],
                   "Age":["Under 5 Years", "Under 18 Years", "65 and Older"],
                   "date_y":[2016]*3,
                   "Occurance_y":[5.808350, 22.569256, 18.011521]})

ax = df[["Age","Occurance_x", "Occurance_y"]].plot(x='Age',
                                                      kind='bar', 
                                                      color=["b","r"],
                                                      rot=45)
ax.set(title = 'Age Demographic by Party', ylabel= 'Mean Percentage')
ax.legend(["Democrat", "Republican"]);

# %%
PercentFemaleDem = MERGED_DATA.loc[democraticPARTY, 'Percent Female']
MERGED_DATA['Percent Male'] = 100 - MERGED_DATA['Percent Female']
print("Female Democrat")
PercentFemaleDem.describe()
# Out:
# Female Democrat
# count    570.000000
# mean      49.959825
# std        2.671259
# min       30.200000
# 25%       49.500000
# 50%       50.550000
# 75%       51.375000
# max       55.200000
# Name: Percent Female, dtype: float64

# %%
MERGED_DATA.head()
# Out:
#     County State  Ben Carson.Number of Votes Ben Carson.Party  \
# 0  Clinton    IN                           0       Republican
# 1     Cass    NE                           0       Republican
# 2   Walton    GA                        1046       Republican
# 3  Norfolk    MA                          38       Republican
# 4   Beaver    PA                           0       Republican
#
#    Ben Carson.Percent of Votes  Bernie Sanders.Number of Votes  \
# 0                          0.0                            1046
# 1                          0.0                             151
# 2                          5.5                             969
# 3                          2.2                             956
# 4                          0.0                            9563
#
#   Bernie Sanders.Party  Bernie Sanders.Percent of Votes  \
# 0             Democrat                             59.1
# 1             Democrat                             53.4
# ...

# %%
PercentMaleDem = MERGED_DATA.loc[democraticPARTY, 'Percent Male']
print("Male Democrat")
PercentMaleDem.describe()
# Out:
# Male Democrat
# count    570.000000
# mean      50.040175
# std        2.671259
# min       44.800000
# 25%       48.625000
# 50%       49.450000
# 75%       50.500000
# max       69.800000
# Name: Percent Male, dtype: float64

# %%
PercentFemaleRep = MERGED_DATA.loc[republicanPARTY, 'Percent Female']
print("Female Republican")
PercentFemaleRep.describe()
# Out:
# Female Republican
# count    1545.000000
# mean       49.943819
# std         2.193263
# min        30.100000
# 25%        49.500000
# 50%        50.400000
# 75%        51.000000
# max        56.800000
# Name: Percent Female, dtype: float64

# %%
PercentMaleRep = MERGED_DATA.loc[republicanPARTY, 'Percent Male']
PercentMaleRep.describe()
# Out:
# count    1545.000000
# mean       50.056181
# std         2.193263
# min        43.200000
# 25%        49.000000
# 50%        49.600000
# 75%        50.500000
# max        69.900000
# Name: Percent Male, dtype: float64

# %%
#Graph comparing gender percentages between both of the parties
df = pd.DataFrame({"date_x":[2015]*2,
                   "Occurance_x":[PercentFemaleDem.mean(), PercentMaleDem.mean()],
                   "Party":["Democratic", "Republican"],
                   "date_y":[2016]*2,
                   "Occurance_y":[PercentFemaleRep.mean(), PercentMaleRep.mean()]})

ax = df[["Party","Occurance_x", "Occurance_y"]].plot(x='Party',
                                                      kind='bar', 
                                                      color=["pink","b"],
                                                      rot=45)
ax.set(title = 'Gender Demographic by Party', ylabel= 'Mean Percentage')
ax.legend(["Female", "Male"]);

# %%
PercentWhiteDem = MERGED_DATA.loc[democraticPARTY, 'Percent White']
PercentBlackDem = MERGED_DATA.loc[democraticPARTY, 'Percent Black or African American']
PercentAmerIndianDem = MERGED_DATA.loc[democraticPARTY, 'Percent American Indian and Alaska Native']
PercentAsianDem = MERGED_DATA.loc[democraticPARTY, 'Percent Asian']
PercentNHDem = MERGED_DATA.loc[democraticPARTY, 'Percent Native Hawaiian and Other Pacific Islander']
Percent2OrMoreDem = MERGED_DATA.loc[democraticPARTY, 'Percent Two or More Races']
PercentHispanicDem = MERGED_DATA.loc[democraticPARTY, 'Percent Hispanic or Latino']

PercentWhiteDem.describe(), PercentBlackDem.describe(), PercentAmerIndianDem.describe(),PercentAsianDem.describe(),PercentNHDem.describe(), Percent2OrMoreDem.describe(), PercentHispanicDem.describe()
# Out:
# (count    570.000000
#  mean      77.036667
#  std       22.195718
#  min       10.800000
#  25%       64.450000
#  50%       87.600000
#  75%       94.575000
#  max       98.800000
#  Name: Percent White, dtype: float64, count    570.000000
#  mean      15.024561
#  std       21.312544
#  min        0.100000
#  25%        1.000000
#  50%        3.500000
#  75%       20.750000
#  max       85.100000
#  Name: Percent Black or African American, dtype: float64, count    570.000000
#  mean       3.072456
#  std        9.239017
#  min        0.100000
#  25%        0.300000
#  50%        0.600000
#  75%        1.500000
#  max       86.200000
#  Name: Percent American Indian and Alaska Native, dtype: float64, count    570.000000
#  mean       2.415439
#  std        4.666544
#  min        0.000000
#  25%        0.400000
#  50%        0.800000
#  75%        2.150000
#  max       42.400000
#  Name: Percent Asian, dtype: float64, count    570.000000
#  mean       0.173509
# ...

# %%
PercentWhiteRep = MERGED_DATA.loc[republicanPARTY, 'Percent White']
PercentBlackRep = MERGED_DATA.loc[republicanPARTY, 'Percent Black or African American']
PercentAmerIndianRep = MERGED_DATA.loc[republicanPARTY, 'Percent American Indian and Alaska Native']
PercentAsianRep = MERGED_DATA.loc[republicanPARTY, 'Percent Asian']
PercentNHRep = MERGED_DATA.loc[republicanPARTY, 'Percent Native Hawaiian and Other Pacific Islander']
Percent2OrMoreRep = MERGED_DATA.loc[republicanPARTY, 'Percent Two or More Races']
PercentHispanicRep = MERGED_DATA.loc[republicanPARTY, 'Percent Hispanic or Latino']
PercentWhiteRep.describe(), PercentBlackRep.describe(), PercentAmerIndianRep.describe(),PercentAsianRep.describe(),PercentNHRep.describe(), Percent2OrMoreRep.describe(), PercentHispanicRep.describe()
# Out:
# (count    1545.000000
#  mean       87.849903
#  std        11.644554
#  min        34.800000
#  25%        83.500000
#  50%        92.400000
#  75%        96.300000
#  max        99.300000
#  Name: Percent White, dtype: float64, count    1545.000000
#  mean        7.878770
#  std        11.016674
#  min         0.000000
#  25%         0.700000
#  50%         2.400000
#  75%        10.300000
#  max        57.400000
#  Name: Percent Black or African American, dtype: float64, count    1545.000000
#  mean        1.400906
#  std         3.899311
#  min         0.000000
#  25%         0.300000
#  50%         0.500000
#  75%         1.100000
#  max        58.800000
#  Name: Percent American Indian and Alaska Native, dtype: float64, count    1545.000000
#  mean        1.061489
#  std         1.491617
#  min         0.000000
#  25%         0.400000
#  50%         0.600000
#  75%         1.100000
#  max        19.000000
#  Name: Percent Asian, dtype: float64, count    1545.000000
# ...

# %%
#Graph comparing ethnicity percentages between both of the parties
df = pd.DataFrame({"date_x":[2015]*7,
                   "Occurance_x":[PercentWhiteDem.mean(), PercentBlackDem.mean(), PercentAmerIndianDem.mean(),
                                 PercentAsianDem.mean(), PercentNHDem.mean(), 
                                  Percent2OrMoreDem.mean(),PercentHispanicDem.mean() ],
                   "Ethnicity":["White", "Black", "A.Indian/\nAlaskan", "Asian", "Native Hawaiian/\nPacific",
                           "2 or More Races", "Hispanic and Latino"],
                   "date_y":[2016]*7,
                   "Occurance_y":[PercentWhiteRep.mean(), PercentBlackRep.mean(), PercentAmerIndianRep.mean(),
                                 PercentAsianRep.mean(), PercentNHRep.mean(), 
                                  Percent2OrMoreRep.mean(),PercentHispanicRep.mean() ]})

ax = df[["Ethnicity","Occurance_x", "Occurance_y"]].plot(x='Ethnicity',
                                                      kind='bar', 
                                                      color=["b","r"],
                                                      rot=45)
ax.set(title = 'Ethnicity Demographic by Party', ylabel= 'Mean Percentage')
ax.legend(["Democrat", "Republican"]);

# %%
#-------------------------------------------------
#Education
PercentHSOrHigherDem = MERGED_DATA.loc[democraticPARTY, 'Percent High School or Higher']
PercentBachelorOrHigherDem = MERGED_DATA.loc[democraticPARTY, "Percent Bachelor's Degree or Higher"]

PercentHSOrHigherRep = MERGED_DATA.loc[republicanPARTY, 'Percent High School or Higher']
PercentBachelorOrHigherRep = MERGED_DATA.loc[republicanPARTY, "Percent Bachelor's Degree or Higher"]

print("Democrat"), PercentHSOrHigherDem.describe(), PercentBachelorOrHigherDem.describe()
# Out:
# Democrat
# (None, count    570.000000
#  mean      83.197544
#  std        8.474581
#  min       45.000000
#  25%       77.700000
#  50%       84.800000
#  75%       89.775000
#  max       97.500000
#  Name: Percent High School or Higher, dtype: float64, count    570.000000
#  mean      22.489474
#  std       12.064380
#  min        5.100000
#  25%       13.000000
#  50%       18.900000
#  75%       29.100000
#  max       74.400000
#  Name: Percent Bachelor's Degree or Higher, dtype: float64)

# %%
 print("Republican"), PercentHSOrHigherRep.describe(), PercentBachelorOrHigherRep.describe()
# Out:
# Republican
# (None, count    1545.000000
#  mean       84.414628
#  std         6.477171
#  min        55.200000
#  25%        80.200000
#  50%        85.500000
#  75%        89.300000
#  max        99.000000
#  Name: Percent High School or Higher, dtype: float64, count    1545.000000
#  mean       18.579029
#  std         7.333633
#  min         5.600000
#  25%        13.500000
#  50%        17.000000
#  75%        21.700000
#  max        57.900000
#  Name: Percent Bachelor's Degree or Higher, dtype: float64)

# %%
#Graph comparing Education percentages between both of the parties
df = pd.DataFrame({"date_x":[2015]*2,
                   "Occurance_x":[PercentHSOrHigherDem.mean(), PercentBachelorOrHigherDem.mean()],
                   "Education":["High School or Higher", "Bachelor's Degree or Higher"],
                   "date_y":[2016]*2,
                   "Occurance_y":[PercentHSOrHigherRep.mean(), PercentBachelorOrHigherRep.mean()]})

ax = df[["Education","Occurance_x", "Occurance_y"]].plot(x='Education',
                                                      kind='bar', 
                                                      color=["b","r"],
                                                      rot=45)
ax.set(title = 'Education Demographic by Party', ylabel= 'Mean Percentage')
ax.legend(["Dem.", "Rep."]);
